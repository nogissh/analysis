# %% [markdown]
# # XGBoostのサンプル
#
# 参考 https://qiita.com/ganmo0911/items/478be76c5029fff15029

# %%
import pandas as pd
import xgboost as xgb
from sklearn.datasets import load_boston

# %%
boston = load_boston()
df_boston = pd.DataFrame(boston.data, columns=boston.feature_names)

df_boston['PRICE'] = boston.target
print(df_boston.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
from sklearn.model_selection import train_test_split

x = df_boston.loc[:,'CRIM':'LSTAT']
y = df_boston['PRICE']

trainX, testX, trainY, testY = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.metrics import mean_squared_error

reg = xgb.XGBRegressor()
reg.fit(trainX, trainY, eval_set=[(trainX, trainY),(testX, testY)])

predY = reg.predict(testX)
# Out:
# [0]	validation_0-rmse:17.40607	validation_1-rmse:16.30409
# [1]	validation_0-rmse:12.58316	validation_1-rmse:11.77693
# [2]	validation_0-rmse:9.15165	validation_1-rmse:8.74644
# [3]	validation_0-rmse:6.76356	validation_1-rmse:6.55093
# [4]	validation_0-rmse:5.04903	validation_1-rmse:5.15193
# [5]	validation_0-rmse:3.83196	validation_1-rmse:4.27629
# [6]	validation_0-rmse:2.99000	validation_1-rmse:3.71203
# [7]	validation_0-rmse:2.39478	validation_1-rmse:3.40859
# [8]	validation_0-rmse:1.96080	validation_1-rmse:3.20517
# [9]	validation_0-rmse:1.66842	validation_1-rmse:3.07287
# [10]	validation_0-rmse:1.45358	validation_1-rmse:3.03226
# [11]	validation_0-rmse:1.29413	validation_1-rmse:2.98581
# [12]	validation_0-rmse:1.20836	validation_1-rmse:2.96164
# [13]	validation_0-rmse:1.11061	validation_1-rmse:2.93879
# [14]	validation_0-rmse:1.03600	validation_1-rmse:2.91779
# [15]	validation_0-rmse:0.92243	validation_1-rmse:2.91948
# [16]	validation_0-rmse:0.81551	validation_1-rmse:2.89955
# [17]	validation_0-rmse:0.73990	validation_1-rmse:2.91235
# [18]	validation_0-rmse:0.70420	validation_1-rmse:2.90393
# [19]	validation_0-rmse:0.64016	validation_1-rmse:2.88729
# [20]	validation_0-rmse:0.60826	validation_1-rmse:2.88539
# [21]	validation_0-rmse:0.58302	validation_1-rmse:2.87477
# [22]	validation_0-rmse:0.53555	validation_1-rmse:2.88511
# [23]	validation_0-rmse:0.49302	validation_1-rmse:2.89138
# [24]	validation_0-rmse:0.44632	validation_1-rmse:2.88839
# [25]	validation_0-rmse:0.42096	validation_1-rmse:2.88698
# [26]	validation_0-rmse:0.40512	validation_1-rmse:2.89158
# [27]	validation_0-rmse:0.39413	validation_1-rmse:2.88975
# [28]	validation_0-rmse:0.36773	validation_1-rmse:2.88887
# [29]	validation_0-rmse:0.35111	validation_1-rmse:2.87480
# [30]	validation_0-rmse:0.31342	validation_1-rmse:2.86150
# [31]	validation_0-rmse:0.29210	validation_1-rmse:2.85832
# [32]	validation_0-rmse:0.28070	validation_1-rmse:2.85711
# [33]	validation_0-rmse:0.26414	validation_1-rmse:2.85633
# [34]	validation_0-rmse:0.25292	validation_1-rmse:2.85862
# [35]	validation_0-rmse:0.23943	validation_1-rmse:2.85519
# [36]	validation_0-rmse:0.22817	validation_1-rmse:2.85674
# [37]	validation_0-rmse:0.22046	validation_1-rmse:2.85493
# [38]	validation_0-rmse:0.21382	validation_1-rmse:2.85789
# [39]	validation_0-rmse:0.20555	validation_1-rmse:2.85710
# [40]	validation_0-rmse:0.19212	validation_1-rmse:2.85662
# [41]	validation_0-rmse:0.18163	validation_1-rmse:2.85782
# [42]	validation_0-rmse:0.16398	validation_1-rmse:2.85667
# [43]	validation_0-rmse:0.15699	validation_1-rmse:2.85796
# [44]	validation_0-rmse:0.14325	validation_1-rmse:2.85721
# [45]	validation_0-rmse:0.13926	validation_1-rmse:2.85689
# [46]	validation_0-rmse:0.13447	validation_1-rmse:2.86016
# [47]	validation_0-rmse:0.12865	validation_1-rmse:2.85834
# [48]	validation_0-rmse:0.12285	validation_1-rmse:2.85726
# [49]	validation_0-rmse:0.11541	validation_1-rmse:2.85823
# [50]	validation_0-rmse:0.11329	validation_1-rmse:2.85645
# [51]	validation_0-rmse:0.10645	validation_1-rmse:2.85369
# [52]	validation_0-rmse:0.10215	validation_1-rmse:2.85210
# [53]	validation_0-rmse:0.09876	validation_1-rmse:2.85282
# [54]	validation_0-rmse:0.09446	validation_1-rmse:2.85310
# [55]	validation_0-rmse:0.08595	validation_1-rmse:2.85309
# [56]	validation_0-rmse:0.08147	validation_1-rmse:2.85300
# [57]	validation_0-rmse:0.07694	validation_1-rmse:2.85324
# [58]	validation_0-rmse:0.07288	validation_1-rmse:2.85360
# [59]	validation_0-rmse:0.07071	validation_1-rmse:2.85285
# [60]	validation_0-rmse:0.06577	validation_1-rmse:2.85233
# [61]	validation_0-rmse:0.06341	validation_1-rmse:2.85203
# [62]	validation_0-rmse:0.06089	validation_1-rmse:2.85214
# [63]	validation_0-rmse:0.05986	validation_1-rmse:2.85138
# [64]	validation_0-rmse:0.05742	validation_1-rmse:2.85229
# [65]	validation_0-rmse:0.05545	validation_1-rmse:2.85161
# [66]	validation_0-rmse:0.05251	validation_1-rmse:2.85155
# [67]	validation_0-rmse:0.04946	validation_1-rmse:2.85116
# [68]	validation_0-rmse:0.04764	validation_1-rmse:2.85127
# [69]	validation_0-rmse:0.04669	validation_1-rmse:2.85145
# [70]	validation_0-rmse:0.04436	validation_1-rmse:2.85206
# [71]	validation_0-rmse:0.04117	validation_1-rmse:2.85245
# [72]	validation_0-rmse:0.03947	validation_1-rmse:2.85273
# [73]	validation_0-rmse:0.03738	validation_1-rmse:2.85296
# [74]	validation_0-rmse:0.03581	validation_1-rmse:2.85284
# [75]	validation_0-rmse:0.03477	validation_1-rmse:2.85307
# [76]	validation_0-rmse:0.03391	validation_1-rmse:2.85304
# [77]	validation_0-rmse:0.03320	validation_1-rmse:2.85284
# [78]	validation_0-rmse:0.03125	validation_1-rmse:2.85276
# [79]	validation_0-rmse:0.03053	validation_1-rmse:2.85269
# [80]	validation_0-rmse:0.02902	validation_1-rmse:2.85296
# [81]	validation_0-rmse:0.02667	validation_1-rmse:2.85333
# [82]	validation_0-rmse:0.02479	validation_1-rmse:2.85373
# [83]	validation_0-rmse:0.02355	validation_1-rmse:2.85375
# [84]	validation_0-rmse:0.02255	validation_1-rmse:2.85353
# [85]	validation_0-rmse:0.02175	validation_1-rmse:2.85326
# [86]	validation_0-rmse:0.01984	validation_1-rmse:2.85268
# [87]	validation_0-rmse:0.01966	validation_1-rmse:2.85291
# [88]	validation_0-rmse:0.01857	validation_1-rmse:2.85307
# [89]	validation_0-rmse:0.01807	validation_1-rmse:2.85323
# [90]	validation_0-rmse:0.01692	validation_1-rmse:2.85308
# [91]	validation_0-rmse:0.01626	validation_1-rmse:2.85307
# [92]	validation_0-rmse:0.01589	validation_1-rmse:2.85300
# [93]	validation_0-rmse:0.01569	validation_1-rmse:2.85294
# [94]	validation_0-rmse:0.01418	validation_1-rmse:2.85301
# [95]	validation_0-rmse:0.01347	validation_1-rmse:2.85311
# [96]	validation_0-rmse:0.01313	validation_1-rmse:2.85311
# [97]	validation_0-rmse:0.01223	validation_1-rmse:2.85313
# [98]	validation_0-rmse:0.01169	validation_1-rmse:2.85314
# [99]	validation_0-rmse:0.01103	validation_1-rmse:2.85304

# %%
for a, b in zip(testY, predY):
    print(a, b)
# Out:
# 16.8 19.47247
# 19.4 21.574413
# 28.5 31.133865
# 11.7 15.097866
# 33.1 31.220425
# 13.9 11.657581
# 19.6 20.286835
# 16.2 19.249441
# 35.2 36.740143
# 21.4 20.862343
# 24.5 22.76341
# 18.4 18.103958
# 9.6 12.106604
# 19.3 19.893017
# 46.0 45.92945
# 31.7 35.98657
# 13.8 12.585789
# 13.8 17.616278
# 9.7 9.809809
# 17.2 17.503471
# 18.4 15.188007
# 10.5 7.8829865
# 24.2 24.438938
# 29.6 26.725302
# 30.1 24.686966
# 18.9 20.632328
# 5.0 7.288218
# 29.1 24.655056
# 13.8 14.357644
# 23.2 18.729794
# 16.5 18.112299
# 10.4 15.35874
# 13.4 11.422786
# 26.4 23.57588
# 16.1 17.701786
# 27.5 26.1326
# 37.3 35.862072
# 20.0 18.457579
# 15.1 15.187434
# 11.9 19.935944
# 21.4 24.399067
# 23.4 21.738535
# 20.1 18.693766
# 19.2 19.294315
# 27.5 24.753092
# 14.6 15.172757
# 21.8 18.805635
# 28.1 25.25895
# 24.1 25.205618
# 36.5 35.252552
# 50.0 48.162827
# 22.4 21.93323
# 23.1 22.9342
# 17.0 17.745619
# 19.6 21.120506
# 23.1 20.888483
# 27.1 25.401817
# 37.0 30.145065
# 14.5 13.860192
# 24.7 22.629093
# 22.9 21.944416
# 26.5 25.450489
# 19.4 17.835552
# 15.7 17.678339
# 29.4 29.307558
# 22.6 21.310673
# 12.7 12.390183
# 20.0 20.600113
# 13.1 7.7249355
# 32.7 32.25321
# 18.9 13.604779
# 16.6 22.170399
# 16.4 17.620426
# 19.4 17.515005
# 23.0 20.121267
# 20.2 19.74288
# 17.8 20.216711
# 41.3 34.651295
# 17.5 16.688684
# 10.4 7.4861836
# 20.6 20.672407
# 8.5 13.520114
# 7.2 7.903145
# 48.8 45.616886
# 36.4 35.693657
# 20.1 19.310024
# 23.9 21.987339
# 13.3 15.116713
# 12.8 12.120844
# 24.7 23.996603
# 26.6 30.817705
# 15.0 29.727783
# 21.7 20.97406
# 22.0 21.953135
# 18.7 20.216213
# 33.4 33.609024
# 22.0 22.219177
# 12.6 14.328939
# 20.1 19.168777
# 23.9 22.68542
# 21.4 19.865149
# 15.3 22.394869
# 22.6 21.063652
# 14.3 16.53154
# 34.9 33.311283
# 25.0 27.08788
# 19.3 19.422298
# 50.0 41.483578
# 14.6 17.933884
# 10.5 6.2745113
# 23.2 22.582815
# 17.2 17.407911
# 11.0 9.11825
# 8.3 11.031651
# 22.5 20.311747
# 16.7 14.655103
# 18.7 17.093754
# 25.0 25.211882
# 24.6 25.872807
# 19.9 20.455204
# 42.3 46.59037
# 18.9 21.884016
# 19.1 19.271124
# 37.9 40.72435
# 43.8 42.610474
# 28.2 29.78089
# 20.3 21.793564
# 22.5 21.741434
# 17.8 16.580769
# 14.8 14.325834
# 16.1 18.665771
# 24.0 23.06569
# 46.7 45.716946
# 15.6 16.89262
# 10.2 16.697453
# 32.2 30.373037
# 22.4 23.301111
# 14.4 20.03409
# 13.3 13.477176
# 20.6 20.381304
# 7.5 9.126587
# 23.9 26.562353
# 17.2 17.195036
# 18.5 18.709167
# 20.0 17.097763
# 34.6 34.267056
# 21.2 19.98028
# 22.0 24.916012
# 18.1 16.504713
# 20.9 21.21068
# 14.9 16.275541
# 13.2 14.290956
